# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/python_data_basic/blob/main/1%EC%9E%A5/01_jupyter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 간단한 코드실행해보기

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
3+5
# Out:
# 8

# %%
5*9
# Out:
# 45

# %%
# 주석은 실행되지 않습니다
# ctrl + / 를 함께 누르면
# 해당 구문이 주석으로 변경됩니다.

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# The Jupyter Notebook is the original web application for creating and sharing computational documents. It offers a simple, streamlined, document-centric experience. [[Site]](https://jupyter.org/)

# %%
## 셀(Cell): 코드를 입력하고 실행

# %% [markdown]
# ## 주요 메뉴

# %% [markdown]
# ![](https://jupyter-notebook.readthedocs.io/en/stable/_images/blank-notebook-ui.png)

# %% [markdown]
# ## 주요 단축키
#
# 단축키 실행 전에 esc를 먼저 눌러주자
#
# - a(above): 현재 셀 위에 셀 추가
# - b(below): 현재 셀 아래에 셀 추가
# - dd(delete): 선택한 셀 삭제
# - shift + enter: 셀 실행 후 활성화 셀을 아래로 이동

# %%
# 주요 단축키 연습

# %% [markdown]
# ----
# # 마크다운

# %% [markdown]
# # 헤더 1
# ## 헤더 2
# ### 헤더 3
# #### 헤더 4
# ##### 헤더 5
#
# 마크다운 모드는 셀 편집 모드에서 m 을 눌러 변경합니다.

# %% [markdown]
# ## 리스트

# %% [markdown]
# ### 순서가 없는 리스트 만들기
# * 하나
# * 둘
# * 셋

# %% [markdown]
# ### 순서가 있는 리스트 만들기
# 1. 하나
# 2. 둘
# 3. 셋

# %% [markdown]
# ### 탭을 이용한 순서가 없는 서브리스트
# * 첫번째
#      - 서브리스트 1
#          - 아이템 1
#          - 아이템 2
#      - 서브리스트 2
#         - 아이템 3
# * 두번째
#      - 서브리스트 3

# %% [markdown]
# ### 탭을 이용한 순서가 있는 서브리스트
# 1. 첫번째
#  1. 서브리스트 1
#  2. 서브리스트 2
# 2. 두번째
# 3. 세번째

# %% [markdown]
# ## 구분선 넣기
# ------------------------------

# %% [markdown]
# ## 글자 효과
#
#
# **굵게**
#
#
# <u>밑줄</u>
#
#
# ~~취소선~~
#
#
# *기울이기*

# %% [markdown]
# ## 표
# | 번호 | 이름 |
# |------|------|
# | 1 | 개구리|
# | 2 | 도마뱀|

# %% [markdown]
# ## 이미지
#
# <img src="https://www.python.org/static/img/python-logo.png"/>

# %% [markdown]
# ## 인용글
#
# > 산토끼 토끼야
# > 어디를 가느냐
# > 깡총깡총 뛰면서
# > 어디를 가느냐

# %% [markdown]
# ## 수식

# %% [markdown]
# $(x-1)^2 + \sqrt{x^2-4x +1}$
#
# [수식 작성 방법 예제](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html)
