# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/python_data_basic/blob/main/2%EC%9E%A5/02_08_%EB%AA%A8%EB%93%88_%ED%81%B4%EB%9E%98%EC%8A%A4_%ED%8C%A8%ED%82%A4%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 패키지, 모듈, 클래스, 함수

# %% [markdown]
# ![image-20230119211822090.png](data:image/png;base64,...)

# %% [markdown]
# ## 클래스, 객체

# %% [markdown]
# ![image-20230119211843101.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.8.3 모듈 불러오기

# %%
import diet
diet.get_recommend_weight(160, False)
# Out:
# 권장 체중은 60kg 입니다
# 60

# %%
import diet as dd
dd.get_recommend_weight(160, False)
# Out:
# 권장 체중은 60kg 입니다
# 60

# %%
dd.print_valid_menu()
# Out:
# 고구마:O
# 떡볶이:X
# 라면:X

# %%
dd.menu
# Out:
# {'고구마': 200, '떡볶이': 600, '라면': 800}

# %%
from diet import get_recommend_weight, print_valid_menu
get_recommend_weight(160, False)
# Out:
# 권장 체중은 60kg 입니다
# 60

# %%
print_valid_menu()
# Out:
# 고구마:O
# 떡볶이:X
# 라면:X
